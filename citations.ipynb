# %%
<cite id="ecjhj"><a href="#zotero%7C16470964%2FP6NINCT7">(Rother et al., 2022)</a></cite>

# %%
<cite id="3rhtd"><a href="#zotero%7C16470964%2FBLEZ7TJN">(Rother et al., 2026)</a></cite>

# %%
<cite id="6o1t4"><a href="#zotero%7C16470964%2F9GLBN5IU">(Turner, 2016)</a></cite>

# %%
<cite id="nkqkh"><a href="#zotero%7C16470964%2F88FTBWT3">(Durrant, 2026)</a></cite>

# %%
<cite id="tifqr"><a href="#zotero%7C16470964%2FQRVJIED8">(Economou &#38; Kist, 2024)</a></cite>

# %%
<cite id="qsmhh"><a href="#zotero%7C16470964%2F28X4NHXD">(Jones, 2018)</a></cite>

# %%
<cite id="05wiq"><a href="#zotero%7C16470964%2FI7GQ384A">(Ben-David, 2016)</a></cite>

# %%
<cite id="h7fzd"><a href="#zotero%7C16470964%2FHMKSLWDS">(Brugger, 2021)</a></cite>

# %%
<cite id="ecbej"><a href="#zotero%7C16470964%2FD2JVCJD6">(Samar et al., 2014)</a></cite>

# %%
<cite id="8haen"><a href="#zotero%7C16470964%2FR3AD4M29">(Maemura et al., 2018)</a></cite>

# %%
<cite id="5hzcl"><a href="#zotero%7C16470964%2FPSWTVEVI">(Povroznik, 2026)</a></cite>

# %%
<cite id="ih813"><a href="#zotero%7C16470964%2FCSTSCA42">(<i>Rijksstudio. Snapshot on 23.10.2018. Internet Archive, Wayback Machine</i>, n.d.)</a></cite>

# %%
<cite id="52nma"><a href="#zotero%7C16470964%2F5LJVV378">(<i>Wayback Machine APIs | Internet Archive</i>, n.d.)</a></cite>

# %%
<cite id="9gvln"><a href="#zotero%7C16470964%2FVGG6R78X">(NadiaPov, 2026/2026)</a></cite>

# %%
<cite id="fjysq"><a href="#zotero%7C16470964%2FUXMZXQBE">(<i>Rijksmuseum Data Services</i>, n.d.)</a></cite>
